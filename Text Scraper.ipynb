# %% [markdown]
# # Project Outline
# This is a scraper to scrape medium articles.

# %%
import requests as r
from bs4 import BeautifulSoup as bs
import json
import pandas

# %%
req = r.get('https://towardsdatascience.com')
soup = bs(req.text,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:cc="http://creativecommons.org/ns#">
#  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# medium-com: http://ogp.me/ns/fb/medium-com#">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1.0, viewport-fit=contain" name="viewport"/>
#   <title>
#    Towards Data Science
#   </title>
#   <link href="https://towardsdatascience.com" rel="canonical"/>
#   <link href="https://towardsdatascience.com/feed" id="feedLink" rel="alternate" title="RSS" type="application/rss+xml"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="Towards Data Science" name="title"/>
#   <meta content="unsafe-url" name="referrer"/>
#   <meta content="A Medium publication sharing concepts, ideas, and codes." name="description"/>
#   <meta content="DATA SCIENCE, MACHINE LEARNING, ARTIFICIAL INTELLIGENCE, ANALYTICS, PROGRAMMING" name="keywords"/>
# ...

# %%
# get the articles section
page = soup.find(class_="u-marginBottom40 js-collectionStream")

# %%
print(page.prettify())
# Out:
# <div class="u-marginBottom40 js-collectionStream">
#  <div class="streamItem streamItem--section js-streamItem">
#   <section class="u-marginTop30 u-xs-margin0 u-marginBottom15 u-maxWidth1032 u-sm-paddingLeft20 u-sm-paddingRight20 u-borderBox u-marginAuto">
#    <div class="row u-marginTop30 u-marginLeftNegative12 u-marginRightNegative12">
#     <div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size6of12" data-index="0" data-post-id="1824e7024cd2" data-source="collection_home---4------0-----------------------">
#      <div class="u-lineHeightBase postItem">
# ...

# %%
titles = soup.find_all(class_ = 'u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24')
len(titles)
# Out:
# 11

# %%
titles
# Out:
# [<div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">How to Use Causal Inference in Day-to-Day Analytical Work— Part 2 of 2</div>,
#  <div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">The curious case of developmental BERTology</div>,
#  <div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Using sentence embeddings to explore the similarities and differences in song lyrics</div>,
#  <div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">My 3-year journey: From zero Python to Deep Learning competition master</div>,
#  <div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Explaining Reinforcement Learning for Beginners based on AWS DeepRacer</div>,
# ...

# %%
for title in titles:
    print(title.get_text())
# Out:
# How to Use Causal Inference in Day-to-Day Analytical Work— Part 2 of 2
# The curious case of developmental BERTology
# Using sentence embeddings to explore the similarities and differences in song lyrics
# My 3-year journey: From zero Python to Deep Learning competition master
# Explaining Reinforcement Learning for Beginners based on AWS DeepRacer
# I know eight ways to merge lists
# How to secure your data career in a recession
# Understanding Statistics And Probability: Bayesian Inference
# GraphQL With Python Flask
# How to Scrape Youtube Comments with Python
# Lecture Notes in Deep Learning: Introduction — Part 4

# %% [markdown]
# ### Blocker
# when requesting access to the towards data science webpage, not all of the content was loaded in. This problem occurs because the content is dynamic and the rest of the webpage is only rendered once we scroll down far enough to reach it.
#
# ### Solution
# Using

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome(executable_path = r'C:\Users\gabe5\Documents\chromedriver\chromedriver.exe')
url = 'https://towardsdatascience.com'
driver.get(url)
soup = bs(driver.page_source,'html.parser')
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-48-eea3f7675bae> in <module>
# ----> 1 driver = webdriver.Chrome(executable_path = r'C:\Users\gabe5\Documents\chromedriver\chromedriver.exe')
#       2 url = 'https://towardsdatascience.com'
#       3 driver.get(url)
#       4 soup = bs(driver.page_source,'html.parser')
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# ...
